# %% [markdown]
# <a href="https://colab.research.google.com/github/mikexie360/data-visualization-final-project/blob/main/data_visualization_final_project_data_collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Collection from OpenDota API for Final Project
# This google colab collects data from the top 5000 teams, team information such as hero picks, win rate and rating. And also their match history from patch 7.33 and up.
#
# Running this google colab can take upwards of a few hours to collect all the data that you need.
# You also might need an OpenDota API Key.

# %%
## imports
import requests
import pandas as pd
from datetime import datetime, timezone
import time

from google.colab import userdata

# %%
# ==== CONFIG ====
OPENDOTA_API_KEY = userdata.get('opendota_api_key')
PATCH_MIN = 7.33        # 7.33 and up
LIMIT = 5000            # keep this moderate; huge pages + JSON can 400
START_OFFSET = 0
MAX_PAGES = None        # None = keep going until empty; or an int
TIMEOUT = 60

API_BASE = "https://api.opendota.com/api"
SLEEP_SEC = 0.25           # gentle rate-limit
MAX_TEAMS = None           # set an int to cap for testing; or None for all

# %%
## teams_df

## top 5000 teams

all_batches = []
for page in range(5):  # pages 0..4
    params = {"api_key": OPENDOTA_API_KEY, "page": page}
    resp = requests.get("https://api.opendota.com/api/teams", params=params, timeout=30)
    resp.raise_for_status()
    batch = resp.json()
    if not batch:
        break
    all_batches.append(pd.DataFrame(batch))

# combine pages
teams_df = pd.concat(all_batches, ignore_index=True)

# add readable timestamp (UTC ISO-8601)
teams_df["last_match_time_iso"] = pd.to_datetime(
    teams_df["last_match_time"], unit="s", utc=True, errors="coerce"
).dt.strftime("%Y-%m-%dT%H:%M:%SZ")

# select/ordering columns
cols = [
    "team_id", "name", "tag", "rating", "wins", "losses",
    "last_match_time", "last_match_time_iso", "logo_url"
]
teams_df = teams_df.reindex(columns=cols)

# write once
teams_df.to_csv("teams.csv", index=False, encoding="utf-8")
print(teams_df.head())
print(f"Number of rows: {len(teams_df)}")
# Out:
#    team_id          name         tag   rating  wins  losses  last_match_time  \
# 0  7119388   Team Spirit     TSpirit  1578.63   768     512       1752941276
# 1  9572001    PARIVISION  PARIVISION  1559.36   179      91       1753691348
# 2  8255888  BetBoom Team     BetBoom  1547.12   502     405       1753694464
# 3  7412785  CyberBonch-1          CB  1520.12   267       1       1639928575
# 4  8605863        Cloud9          C9  1497.49   326     243       1726305637
#
#     last_match_time_iso                                           logo_url
# 0  2025-07-19T16:07:56Z  https://cdn.steamusercontent.com/ugc/183917912...
# 1  2025-07-28T08:29:08Z  https://cdn.steamusercontent.com/ugc/247650869...
# 2  2025-07-28T09:21:04Z  https://cdn.steamusercontent.com/ugc/999542643...
# 3  2021-12-19T15:42:55Z  https://cdn.steamusercontent.com/ugc/184253787...
# 4  2024-09-14T09:20:37Z  https://cdn.steamusercontent.com/ugc/239994188...
# Number of rows: 5000

# %%
## heroes_df

### All heroes in the game

heroes_url = "https://api.opendota.com/api/heroes"
resp = requests.get(heroes_url)
resp.raise_for_status()
data = resp.json()  # <- list of dicts

# optional: turn the roles list into a comma-separated string
for row in data:
    if isinstance(row.get("roles"), list):
        row["roles"] = ",".join(row["roles"])

# pick a column order (optional)
cols = ["id", "name", "localized_name", "primary_attr", "attack_type", "roles", "legs"]
heroes_df = pd.DataFrame(data)[cols]

heroes_df.to_csv("heroes.csv", index=False, encoding="utf-8")
print(heroes_df.head)
# Out:
# <bound method NDFrame.head of       id                          name  localized_name primary_attr  \
# 0      1        npc_dota_hero_antimage       Anti-Mage          agi
# 1      2             npc_dota_hero_axe             Axe          str
# 2      3            npc_dota_hero_bane            Bane          all
# 3      4     npc_dota_hero_bloodseeker     Bloodseeker          agi
# 4      5  npc_dota_hero_crystal_maiden  Crystal Maiden          int
# ..   ...                           ...             ...          ...
# 121  135     npc_dota_hero_dawnbreaker     Dawnbreaker          str
# 122  136           npc_dota_hero_marci           Marci          all
# 123  137    npc_dota_hero_primal_beast    Primal Beast          str
# 124  138          npc_dota_hero_muerta          Muerta          int
# 125  145             npc_dota_hero_kez             Kez          agi
#
#     attack_type                                    roles  legs
# 0         Melee                       Carry,Escape,Nuker     2
# 1         Melee         Initiator,Durable,Disabler,Carry     2
# 2        Ranged           Support,Disabler,Nuker,Durable     4
# 3         Melee           Carry,Disabler,Nuker,Initiator     2
# 4        Ranged                   Support,Disabler,Nuker     2
# ..          ...                                      ...   ...
# 121       Melee                            Carry,Durable     2
# 122       Melee  Support,Carry,Initiator,Disabler,Escape     2
# 123       Melee               Initiator,Durable,Disabler     2
# 124      Ranged                     Carry,Nuker,Disabler     2
# 125       Melee                    Carry,Escape,Disabler     2
#
# [126 rows x 7 columns]>

# %%
## matches_teams_picks_bans

API = "https://api.opendota.com/api/explorer"

# output filenames
MATCH_TEAMS_CSV = "match_teams_733_plus.csv"
PICKS_BANS_LONG_CSV = "match_picks_bans_long_733_plus.csv"
MATCHES_TEAMS_PB_WIDE_CSV = "matches_teams_picks_bans_733_plus.csv"
# ===================================================

def run_explorer(limit: int, offset: int) -> pd.DataFrame:
    sql = f"""
        SELECT
          m.match_id,
          m.start_time,
          m.radiant_team_id,
          m.dire_team_id,
          m.radiant_win,
          m.duration,
          m.radiant_score,
          m.dire_score,
          m.picks_bans,
          CASE WHEN m.radiant_win THEN m.radiant_team_id ELSE m.dire_team_id END AS winner_team_id,
          m.leagueid,
          l.name AS league_name,
          mp.patch
        FROM matches m
        JOIN match_patch mp USING (match_id)
        LEFT JOIN leagues l ON l.leagueid = m.leagueid
        WHERE m.radiant_team_id IS NOT NULL
          AND m.dire_team_id IS NOT NULL
          AND m.radiant_team_id > 0
          AND m.dire_team_id > 0
          AND NULLIF(regexp_replace(mp.patch, '[^0-9\\.]', '', 'g'), '') IS NOT NULL
          AND CAST(regexp_replace(mp.patch, '[^0-9\\.]', '', 'g') AS numeric) >= {PATCH_MIN}
        ORDER BY m.match_id
        LIMIT {limit} OFFSET {offset}
    """
    params = {"sql": sql}
    if OPENDOTA_API_KEY:
        params["api_key"] = OPENDOTA_API_KEY
    r = requests.get(API, params=params, timeout=TIMEOUT)
    r.raise_for_status()
    return pd.DataFrame(r.json().get("rows", []))

all_match_pages = []
all_pb_rows = []
page = 0
offset = START_OFFSET
prev_sample = None

while True:
    page += 1

    if prev_sample is not None:
        print(f"[Page {page}] Sample of previous page (first 5 rows):")
        print(prev_sample.to_string(index=False))
        print("-" * 80)

    print(f"Fetching page {page} (offset={offset}, limit={LIMIT}) ...")
    df = run_explorer(LIMIT, offset)
    n = len(df)
    print(f"Fetched {n} rows.")
    if n == 0:
        print("No more rows. Stopping.")
        break

    # Preview for next loop
    show_cols = [c for c in ["match_id", "radiant_team_id", "dire_team_id", "league_name", "patch"] if c in df.columns]
    prev_sample = df[show_cols].head(5).copy()

    # Accumulate matches
    all_match_pages.append(df)

    # Build a long-form picks/bans while we have the row context (to resolve team_id)
    if "picks_bans" in df.columns:
        for _, row in df.iterrows():
            match_id = row["match_id"]
            r_tid = row["radiant_team_id"]
            d_tid = row["dire_team_id"]
            pbs = row["picks_bans"]
            if isinstance(pbs, list):
                for pb in pbs:
                    side = pb.get("team")  # 0=radiant, 1=dire
                    team_id = r_tid if side == 0 else d_tid if side == 1 else None
                    all_pb_rows.append({
                        "match_id": match_id,
                        "order": pb.get("order"),
                        "is_pick": pb.get("is_pick"),
                        "hero_id": pb.get("hero_id"),
                        "team_side": side,
                        "team_id": team_id,
                    })

    offset += LIMIT
    if MAX_PAGES is not None and page >= MAX_PAGES:
        print("Reached MAX_PAGES cap. Stopping.")
        break

# ===== Build match_teams_df =====
match_teams_df = pd.concat(all_match_pages, ignore_index=True) if all_match_pages else pd.DataFrame()

# Add ISO timestamp
if "start_time" in match_teams_df.columns:
    match_teams_df["start_time_iso"] = pd.to_datetime(
        match_teams_df["start_time"], unit="s", utc=True, errors="coerce"
    ).dt.strftime("%Y-%m-%dT%H:%M:%SZ")

# Column order
preferred_cols = [
    "match_id",
    "radiant_team_id", "dire_team_id",
    "start_time", "start_time_iso",
    "radiant_win", "winner_team_id",
    "duration", "radiant_score", "dire_score",
    "leagueid", "league_name", "patch", "picks_bans"
]
match_teams_df = match_teams_df[[c for c in preferred_cols if c in match_teams_df.columns] +
                                [c for c in match_teams_df.columns if c not in preferred_cols]]

# ===== Build long-form picks/bans df (already team_id-resolved) =====
match_picks_bans_df = pd.DataFrame(all_pb_rows).sort_values(["match_id", "order"]).reset_index(drop=True)

# ===== Build WIDE matches_teams_picks_bans =====
# For each match row, create: isPick{n}, hero_id{n}, team_id{n}, order{n}
def flatten_picks_bans_row(row) -> dict:
    base = {k: row[k] for k in row.index if k != "picks_bans"}  # copy all except the JSON
    pbs = row.get("picks_bans")
    if isinstance(pbs, list):
        # ensure ordered by "order"
        pbs_sorted = sorted(pbs, key=lambda x: x.get("order", 0))
        for pb in pbs_sorted:
            k = int(pb.get("order", 0)) + 1  # 1-based suffix
            side = pb.get("team")  # 0=radiant, 1=dire
            team_id = row["radiant_team_id"] if side == 0 else row["dire_team_id"] if side == 1 else None
            base[f"isPick{k}"] = bool(pb.get("is_pick"))
            base[f"hero_id{k}"] = pb.get("hero_id")
            base[f"team_id{k}"] = team_id
            base[f"order{k}"] = pb.get("order")
    return base

if not match_teams_df.empty:
    wide_records = [flatten_picks_bans_row(r) for _, r in match_teams_df.iterrows()]
    matches_teams_picks_bans = pd.DataFrame(wide_records)
else:
    matches_teams_picks_bans = pd.DataFrame()

# Drop the raw JSON column from match_teams_df before saving (keeps file tidy)
if "picks_bans" in match_teams_df.columns:
    match_teams_df_nojson = match_teams_df.drop(columns=["picks_bans"])
else:
    match_teams_df_nojson = match_teams_df.copy()

# ===== SAVE CSVs =====
match_teams_df_nojson.to_csv(MATCH_TEAMS_CSV, index=False, encoding="utf-8")
match_picks_bans_df.to_csv(PICKS_BANS_LONG_CSV, index=False, encoding="utf-8")
matches_teams_picks_bans.to_csv(MATCHES_TEAMS_PB_WIDE_CSV, index=False, encoding="utf-8")

print("\nDone!")
print("Saved:", MATCH_TEAMS_CSV)
print("Saved:", PICKS_BANS_LONG_CSV)
print("Saved:", MATCHES_TEAMS_PB_WIDE_CSV)

print("\nShapes:")
print("match_teams_df_nojson:", match_teams_df_nojson.shape)
print("match_picks_bans_df:", match_picks_bans_df.shape)
print("matches_teams_picks_bans:", matches_teams_picks_bans.shape)

print("\nPreview matches_teams_picks_bans:")
print(matches_teams_picks_bans.head().to_string(index=False))
# Out:
# Fetching page 1 (offset=0, limit=5000) ...
# Fetched 5000 rows.
# [Page 2] Sample of previous page (first 5 rows):
#   match_id  radiant_team_id  dire_team_id                                                         league_name patch
# 7116526799          8680612       8971308 DPC 2023 SA Spring Tour Division II – presented by ESB Liga Esports  7.33
# 7116656225          8893835       8864178                                                     Ancients League  7.33
# 7116662198          8629315       8629318                                                      Destiny league  7.33
# 7116708252          8864178       8893835                                                     Ancients League  7.33
# 7116718813          8863825       8736661          DPC 2023 SEA Spring Tour Division II - presented by Epulze  7.33
# --------------------------------------------------------------------------------
# Fetching page 2 (offset=5000, limit=5000) ...
# Fetched 5000 rows.
# [Page 3] Sample of previous page (first 5 rows):
#   match_id  radiant_team_id  dire_team_id                                            league_name patch
# 7207532027          8230115       8737621            EPL World Series: America 2022-2023 Season   7.33
# 7207536210          6209166       8255756                 DreamLeague Season 20 powered by Intel  7.33
# 7207557779          8686313       8406842 DPC 2023 NA Summer Tour Division II – presented by PGL  7.33
# 7207560762          9104067       8765917                           Ultras Dota Pro League  2023  7.33
# 7207561496          9048057       8879077                                    Dota 2 Space League  7.33
# --------------------------------------------------------------------------------
# Fetching page 3 (offset=10000, limit=5000) ...
# Fetched 5000 rows.
# [Page 4] Sample of previous page (first 5 rows):
#   match_id  radiant_team_id  dire_team_id                              league_name patch
# 7291869205          9005165       9104067             Ultras Dota Pro League  2023  7.34
# 7291886026          8970358       8970053               ESportsBattle | DOTA2 SMC8  7.34
# 7291891738          7453020       9080405 Road to TI 2023 - CN Regional Qualifiers  7.34
# 7291903134          8629327       8629014                           Destiny league  7.34
# 7291939346          9104106       9005165             Ultras Dota Pro League  2023  7.34
# --------------------------------------------------------------------------------
# Fetching page 4 (offset=15000, limit=5000) ...
# Fetched 5000 rows.
# [Page 5] Sample of previous page (first 5 rows):
#   match_id  radiant_team_id  dire_team_id                league_name patch
# 7398448993          8629324       8629005             Destiny league  7.34
# 7398449584          8864178       8893825            Ancients League  7.34
# 7398457146          7356881       9216658         B5vip Championship  7.34
# 7398464998          9109275       9109308 ESportsBattle | DOTA2 AUC6  7.34
# 7398476532          8629327       8629318             Destiny league  7.34
# --------------------------------------------------------------------------------
# Fetching page 5 (offset=20000, limit=5000) ...
# Fetched 5000 rows.
# [Page 6] Sample of previous page (first 5 rows):
#   match_id  radiant_team_id  dire_team_id                       league_name patch
# 7512282180          9270745       9229377   Ultras Dota Pro League  2023-24  7.35
# 7512282306          8971308       9283988 FastInvitational DotaPRO Season 2  7.35
# 7512299758          8936613       8957156               Dota 2 Space League  7.35
# 7512338155          9229377       9270745   Ultras Dota Pro League  2023-24  7.35
# 7512354049          8957156       8936613               Dota 2 Space League  7.35
# --------------------------------------------------------------------------------
# Fetching page 6 (offset=25000, limit=5000) ...
# Fetched 5000 rows.
# [Page 7] Sample of previous page (first 5 rows):
#   match_id  radiant_team_id  dire_team_id                            league_name patch
# 7615556063          9088071       9225431        Ultras Dota Pro League  2023-24  7.35
# 7615628356          8367062       9302841                   DSAC Invitational S1  7.35
# 7615645410          9291798       9162417  European Pro League  2023-2024 Season  7.35
# 7615652918          9225431       9088071        Ultras Dota Pro League  2023-24  7.35
# 7615748933          9247354       8599101 DreamLeague Season 22 powered by Intel  7.35
# --------------------------------------------------------------------------------
# Fetching page 7 (offset=30000, limit=5000) ...
# Fetched 5000 rows.
# [Page 8] Sample of previous page (first 5 rows):
#   match_id  radiant_team_id  dire_team_id     league_name patch
# 7718008889          9330492       9330489 Ancients League  7.35
# 7718009592          8629014       8629005  Destiny League  7.35
# 7718020047          2443375       8629318  Destiny League  7.35
# 7718021044          9389381       8944230  Kobolds Rave 2  7.35
# 7718040519          9330489       9330492 Ancients League  7.35
# --------------------------------------------------------------------------------
# Fetching page 8 (offset=35000, limit=5000) ...
# Fetched 5000 rows.
# [Page 9] Sample of previous page (first 5 rows):
#   match_id  radiant_team_id  dire_team_id                              league_name patch
# 7828444011                5       8605863 Riyadh Masters 2024 at Esports World Cup  7.36
# 7828481165          2443375       8629324                           Destiny League  7.36
# 7828498739          9449532       9466943    European Pro League  2023-2024 Season  7.36
# 7828499241          9381131       9360721          Ultras Dota Pro League  2023-24  7.36
# 7828540301          8574561       9467224 Riyadh Masters 2024 at Esports World Cup  7.36
# --------------------------------------------------------------------------------
# Fetching page 9 (offset=40000, limit=5000) ...
# Fetched 5000 rows.
# [Page 10] Sample of previous page (first 5 rows):
#   match_id  radiant_team_id  dire_team_id                     league_name patch
# 7932471657          9525161       6796995            Party To Play league  7.37
# 7932481773          9330961       9277923            Party To Play league  7.37
# 7932528106          9524596       7209981     EPICENTER - 8° TORNEO UNSCH  7.37
# 7932547974          9338738       9223797 Ultras Dota Pro League  2023-24  7.37
# 7932551895          9525221       5406292     EPICENTER - 8° TORNEO UNSCH  7.37
# --------------------------------------------------------------------------------
# Fetching page 10 (offset=45000, limit=5000) ...
# Fetched 5000 rows.
# [Page 11] Sample of previous page (first 5 rows):
#   match_id  radiant_team_id  dire_team_id                                      league_name patch
# 8033602645          8936507       9332046                                  Ancients League  7.37
# 8033609181          8629005       8629324                                   Destiny League  7.37
# 8033614553           350190       9600387 ESL One Bangkok 2024 Qualifiers powered by Intel  7.37
# 8033618137          8629318       2443375                                   Destiny League  7.37
# 8033630134          9538207       9586396 ESL One Bangkok 2024 Qualifiers powered by Intel  7.37
# --------------------------------------------------------------------------------
# Fetching page 11 (offset=50000, limit=5000) ...
# Fetched 5000 rows.
# [Page 12] Sample of previous page (first 5 rows):
#   match_id  radiant_team_id  dire_team_id                     league_name patch
# 8132534285          8961813       8864178                 Ancients League  7.37
# 8132535593          9425656       2443375                  Destiny League  7.37
# 8132537352          9546437       8254145 ESL One Raleigh 2025 Qualifiers  7.37
# 8132543339          9600191       7917893 ESL One Raleigh 2025 Qualifiers  7.37
# 8132553732          2443375       9425656                  Destiny League  7.37
# --------------------------------------------------------------------------------
# Fetching page 12 (offset=55000, limit=5000) ...
# Fetched 5000 rows.
# [Page 13] Sample of previous page (first 5 rows):
#   match_id  radiant_team_id  dire_team_id                     league_name patch
# 8227158497          9255039       9635124      FISSURE Universe Episode 4  7.38
# 8227170216          9425660       8629005                  Destiny League  7.38
# 8227185757          8961813       8893837                 Ancients League  7.38
# 8227198441          9524130       9651831 Ultras Dota Pro League  2024-25  7.38
# 8227203504          9593609       9586420 Ultras Dota Pro League  2024-25  7.38
# --------------------------------------------------------------------------------
# Fetching page 13 (offset=60000, limit=5000) ...
# Fetched 5000 rows.
# [Page 14] Sample of previous page (first 5 rows):
#   match_id  radiant_team_id  dire_team_id         league_name patch
# 8312086566          9005364       8850015 Dota 2 Space League  7.39
# 8312099327          9161995       9168523      NADCL Season 8  7.39
# 8312104478          9729085       9791624      NADCL Season 8  7.39
# 8312105932          9790570       9323845      NADCL Season 8  7.39
# 8312110787          8849850       8850100 Dota 2 Space League  7.39
# --------------------------------------------------------------------------------
# Fetching page 14 (offset=65000, limit=5000) ...
# Fetched 766 rows.
# [Page 15] Sample of previous page (first 5 rows):
#   match_id  radiant_team_id  dire_team_id                             league_name patch
# 8397605965          8261500       9824702 Clavision DOTA2 Masters 2025: Snow-Ruyi  7.39
# 8397617122          9579022       9829371                    Campeonato NEXTLEVEL  7.39
# 8397622915          9005364       8850016                     Dota 2 Space League  7.39
# 8397648250          9824702       8261500 Clavision DOTA2 Masters 2025: Snow-Ruyi  7.39
# 8397660822          8936507       8864178                         Ancients League  7.39
# --------------------------------------------------------------------------------
# Fetching page 15 (offset=70000, limit=5000) ...
# Fetched 0 rows.
# No more rows. Stopping.
#
# Done!
# Saved: match_teams_733_plus.csv
# Saved: match_picks_bans_long_733_plus.csv
# Saved: matches_teams_picks_bans_733_plus.csv
#
# Shapes:
# match_teams_df_nojson: (65766, 13)
# match_picks_bans_df: (1564929, 6)
# matches_teams_picks_bans: (65766, 109)
#
# Preview matches_teams_picks_bans:
#   match_id  radiant_team_id  dire_team_id  start_time       start_time_iso  radiant_win  winner_team_id  duration  radiant_score  dire_score  leagueid                                                         league_name patch isPick1  hero_id1  team_id1  order1 isPick2  hero_id2  team_id2  order2 isPick3  hero_id3  team_id3  order3 isPick4  hero_id4  team_id4  order4 isPick5  hero_id5  team_id5  order5 isPick6  hero_id6  team_id6  order6 isPick7  hero_id7  team_id7  order7 isPick8  hero_id8  team_id8  order8 isPick9  hero_id9  team_id9  order9 isPick10  hero_id10  team_id10  order10 isPick11  hero_id11  team_id11  order11 isPick12  hero_id12  team_id12  order12 isPick13  hero_id13  team_id13  order13 isPick14  hero_id14  team_id14  order14 isPick15  hero_id15  team_id15  order15 isPick16  hero_id16  team_id16  order16 isPick17  hero_id17  team_id17  order17 isPick18  hero_id18  team_id18  order18 isPick19  hero_id19  team_id19  order19 isPick20  hero_id20  team_id20  order20 isPick21  hero_id21  team_id21  order21 isPick22  hero_id22  team_id22  order22 isPick23  hero_id23  team_id23  order23 isPick24  hero_id24  team_id24  order24
# 7116526799          8680612       8971308  1682042521 2023-04-21T02:02:01Z        False         8971308      1849             10          42     15136 DPC 2023 SA Spring Tour Division II – presented by ESB Liga Esports  7.33   False      58.0 8680612.0     0.0   False      75.0 8971308.0     1.0   False      85.0 8680612.0     2.0   False     137.0 8971308.0     3.0    True     101.0 8680612.0     4.0    True     128.0 8971308.0     5.0    True     135.0 8971308.0     6.0    True      52.0 8680612.0     7.0   False       1.0 8680612.0     8.0    False      105.0  8971308.0      9.0    False       11.0  8680612.0     10.0    False       12.0  8971308.0     11.0    False       46.0  8680612.0     12.0    False       94.0  8971308.0     13.0     True      106.0  8971308.0     14.0     True       69.0  8680612.0     15.0     True       71.0  8680612.0     16.0     True       53.0  8971308.0     17.0    False       10.0  8680612.0     18.0    False      109.0  8971308.0     19.0    False       48.0  8680612.0     20.0    False       89.0  8971308.0     21.0     True       93.0  8680612.0     22.0     True       92.0  8971308.0     23.0
# 7116656225          8893835       8864178  1682049626 2023-04-21T04:00:26Z         True         8893835      1718             34          13     15109                                                     Ancients League  7.33   False      76.0 8893835.0     0.0   False      86.0 8864178.0     1.0   False     114.0 8893835.0     2.0   False     138.0 8864178.0     3.0    True     101.0 8893835.0     4.0    True      19.0 8864178.0     5.0    True      64.0 8864178.0     6.0    True     104.0 8893835.0     7.0   False       4.0 8893835.0     8.0    False        6.0  8864178.0      9.0    False       70.0  8893835.0     10.0    False       54.0  8864178.0     11.0    False       93.0  8893835.0     12.0    False       11.0  8864178.0     13.0     True      128.0  8864178.0     14.0     True        8.0  8893835.0     15.0     True        9.0  8893835.0     16.0     True       21.0  8864178.0     17.0    False       10.0  8893835.0     18.0    False       39.0  8864178.0     19.0    False       42.0  8893835.0     20.0    False      106.0  8864178.0     21.0     True      126.0  8893835.0     22.0     True       56.0  8864178.0     23.0
# 7116662198          8629315       8629318  1682050090 2023-04-21T04:08:10Z         True         8629315      2180             43          27     14659                                                      Destiny league  7.33   False      38.0 8629315.0     0.0   False      22.0 8629318.0     1.0   False     138.0 8629315.0     2.0   False     112.0 8629318.0     3.0    True      16.0 8629315.0     4.0    True      51.0 8629318.0     5.0    True      71.0 8629318.0     6.0    True      42.0 8629315.0     7.0   False      68.0 8629315.0     8.0    False      126.0  8629318.0      9.0    False       13.0  8629315.0     10.0    False       40.0  8629318.0     11.0    False       70.0  8629315.0     12.0    False       92.0  8629318.0     13.0     True       90.0  8629318.0     14.0     True       88.0  8629315.0     15.0     True       85.0  8629315.0     16.0     True       93.0  8629318.0     17.0    False       74.0  8629315.0     18.0    False      101.0  8629318.0     19.0    False       23.0  8629315.0     20.0    False       63.0  8629318.0     21.0     True      106.0  8629315.0     22.0     True       56.0  8629318.0     23.0
# 7116708252          8864178       8893835  1682052312 2023-04-21T04:45:12Z         True         8864178      2151             39          20     15109                                                     Ancients League  7.33   False      19.0 8864178.0     0.0   False      43.0 8893835.0     1.0   False     101.0 8864178.0     2.0   False      87.0 8893835.0     3.0    True     138.0 8864178.0     4.0    True      26.0 8893835.0     5.0    True      38.0 8893835.0     6.0    True      86.0 8864178.0     7.0   False      11.0 8864178.0     8.0    False       10.0  8893835.0      9.0    False       63.0  8864178.0     10.0    False      114.0  8893835.0     11.0    False        6.0  8864178.0     12.0    False        4.0  8893835.0     13.0     True       51.0  8893835.0     14.0     True       31.0  8864178.0     15.0     True        2.0  8864178.0     16.0     True       54.0  8893835.0     17.0    False       39.0  8864178.0     18.0    False       76.0  8893835.0     19.0    False       46.0  8864178.0     20.0    False       21.0  8893835.0     21.0     True        9.0  8864178.0     22.0     True       52.0  8893835.0     23.0
# 7116718813          8863825       8736661  1682053231 2023-04-21T05:00:31Z        False         8736661      2584             20          38     15126          DPC 2023 SEA Spring Tour Division II - presented by Epulze  7.33   False     111.0 8863825.0     0.0   False      61.0 8736661.0     1.0   False      65.0 8863825.0     2.0   False     138.0 8736661.0     3.0    True      66.0 8863825.0     4.0    True      58.0 8736661.0     5.0    True      69.0 8736661.0     6.0    True     137.0 8863825.0     7.0   False     114.0 8863825.0     8.0    False      123.0  8736661.0      9.0    False       89.0  8863825.0     10.0    False       45.0  8736661.0     11.0    False      109.0  8863825.0     12.0    False       10.0  8736661.0     13.0     True      106.0  8736661.0     14.0     True       46.0  8863825.0     15.0     True      136.0  8863825.0     16.0     True      110.0  8736661.0     17.0    False       93.0  8863825.0     18.0    False       33.0  8736661.0     19.0    False       12.0  8863825.0     20.0    False       92.0  8736661.0     21.0     True       43.0  8863825.0     22.0     True       95.0  8736661.0     23.0

# %%
## teams_heros_df

OUT_CSV = "team_hero_df.csv"

# --- Helper to fetch a team's hero stats ---
def fetch_team_heroes(team_id: int, api_key: str | None = None, timeout: int = 30) -> pd.DataFrame:
    url = f"{API_BASE}/teams/{team_id}/heroes"
    params = {"api_key": api_key} if api_key else None
    r = requests.get(url, params=params, timeout=timeout)
    r.raise_for_status()
    data = r.json()  # list[dict]
    df = pd.DataFrame(data)
    if df.empty:
        return pd.DataFrame(columns=["team_id", "hero_id"])
    df["team_id"] = team_id
    return df

# --- Optional: hero lookup (id -> names) ---
def get_heroes_lookup() -> pd.DataFrame:
    # Use existing heroes_df if present; else fetch once.
    if "heroes_df" in globals() and isinstance(heroes_df, pd.DataFrame) and "id" in heroes_df.columns:
        h = heroes_df.copy()
    else:
        r = requests.get(f"{API_BASE}/heroes", timeout=30)
        r.raise_for_status()
        h = pd.DataFrame(r.json())
    # Keep common columns; rename id -> hero_id for merge
    keep = [c for c in ["id", "name", "localized_name", "primary_attr", "attack_type"] if c in h.columns]
    h = h[keep].rename(columns={"id": "hero_id"})
    return h

# --- Collect team->hero stats for all teams in teams_df ---
team_ids = teams_df["team_id"].dropna().astype(int).unique()
if MAX_TEAMS is not None:
    team_ids = team_ids[:MAX_TEAMS]

all_frames = []
for i, tid in enumerate(team_ids, start=1):
    try:
        if i == 1:
            print(f"Starting team hero fetch for {len(team_ids)} teams...")
        if i % 50 == 1 or i == len(team_ids):
            print(f"[{i}/{len(team_ids)}] team_id={tid}")
        df = fetch_team_heroes(tid, api_key=OPENDOTA_API_KEY)
        all_frames.append(df)
    except Exception as e:
        print(f"Failed team_id={tid}: {e}")
    time.sleep(SLEEP_SEC)

team_hero_df = pd.concat(all_frames, ignore_index=True) if all_frames else pd.DataFrame()

# --- Add winrate if wins/games columns exist (naming can vary) ---
wins_col = "wins" if "wins" in team_hero_df.columns else ("win" if "win" in team_hero_df.columns else None)
games_col = "games_played" if "games_played" in team_hero_df.columns else ("games" if "games" in team_hero_df.columns else None)
if wins_col and games_col:
    team_hero_df["winrate"] = (team_hero_df[wins_col] / team_hero_df[games_col]).round(4)

# --- Attach hero names (id -> names) ---
try:
    heroes_lookup = get_heroes_lookup()
    team_hero_df = team_hero_df.merge(heroes_lookup, on="hero_id", how="left")
except Exception as e:
    print("Skipping hero name merge:", e)

# --- Nice column order (best-effort; keeps extras at the end) ---
preferred = ["team_id", "hero_id", "localized_name", "name", "primary_attr", "attack_type",
             "games_played", "games", "wins", "win", "winrate"]
ordered = [c for c in preferred if c in team_hero_df.columns]
rest = [c for c in team_hero_df.columns if c not in ordered]
team_hero_df = team_hero_df[ordered + rest]

# --- Save & peek ---
team_hero_df.to_csv(OUT_CSV, index=False, encoding="utf-8")
print("Saved:", OUT_CSV)
print("team_hero_df shape:", team_hero_df.shape)
print(team_hero_df.head().to_string(index=False))
# Out:
# Starting team hero fetch for 5000 teams...
# [1/5000] team_id=7119388
# [51/5000] team_id=9187066
# [101/5000] team_id=9303484
# [151/5000] team_id=8214850
# [201/5000] team_id=8998465
# [251/5000] team_id=8936568
# [301/5000] team_id=1848465
# [351/5000] team_id=9216247
# [401/5000] team_id=3018001
# [451/5000] team_id=2850822
# [501/5000] team_id=8495691
# [551/5000] team_id=1665758
# [601/5000] team_id=8713367
# [651/5000] team_id=7716098
# [701/5000] team_id=7019918
# [751/5000] team_id=2024718
# [801/5000] team_id=8193371
# [851/5000] team_id=7422393
# [901/5000] team_id=8526136
# [951/5000] team_id=2025160
# [1001/5000] team_id=5006832
# [1051/5000] team_id=6435695
# [1101/5000] team_id=9683757
# [1151/5000] team_id=9440022
# [1201/5000] team_id=9466553
# [1251/5000] team_id=7510730
# [1301/5000] team_id=7578716
# [1351/5000] team_id=8604954
# [1401/5000] team_id=8999483
# [1451/5000] team_id=9373820
# [1501/5000] team_id=9530233
# [1551/5000] team_id=2496863
# [1601/5000] team_id=2913028
# [1651/5000] team_id=9126284
# [1701/5000] team_id=1709168
# [1751/5000] team_id=9302584
# [1801/5000] team_id=1626847
# [1851/5000] team_id=8943671
# [1901/5000] team_id=1556353
# [1951/5000] team_id=9623346
# [2001/5000] team_id=1424328
# [2051/5000] team_id=8282364
# [2101/5000] team_id=9388962
# [2151/5000] team_id=5191951
# [2201/5000] team_id=9262645
# [2251/5000] team_id=8359606
# [2301/5000] team_id=7795347
# [2351/5000] team_id=2363730
# [2401/5000] team_id=7470091
# [2451/5000] team_id=6214126
# [2501/5000] team_id=3779325
# [2551/5000] team_id=9504575
# [2601/5000] team_id=2192575
# [2651/5000] team_id=2038546
# [2701/5000] team_id=5128233
# [2751/5000] team_id=1929288
# [2801/5000] team_id=8194049
# [2851/5000] team_id=8022035
# [2901/5000] team_id=1397524
# [2951/5000] team_id=6658355
# [3001/5000] team_id=8188432
# [3051/5000] team_id=8160899
# [3101/5000] team_id=8290971
# [3151/5000] team_id=8690729
# [3201/5000] team_id=3148633
# [3251/5000] team_id=6796440
# [3301/5000] team_id=9055278
# [3351/5000] team_id=5119169
# [3401/5000] team_id=7683937
# [3451/5000] team_id=5475274
# [3501/5000] team_id=7098986
# [3551/5000] team_id=8714167
# [3601/5000] team_id=6408145
# [3651/5000] team_id=3686302
# [3701/5000] team_id=9665161
# [3751/5000] team_id=2610374
# [3801/5000] team_id=2143341
# [3851/5000] team_id=2505675
# [3901/5000] team_id=9640536
# [3951/5000] team_id=7281057
# [4001/5000] team_id=2890277
# [4051/5000] team_id=8765486
# [4101/5000] team_id=7170784
# [4151/5000] team_id=1942710
# [4201/5000] team_id=9366216
# [4251/5000] team_id=2791752
# [4301/5000] team_id=1129602
# [4351/5000] team_id=8457027
# [4401/5000] team_id=6296277
# [4451/5000] team_id=6796311
# [4501/5000] team_id=2915964
# [4551/5000] team_id=6847859
# [4601/5000] team_id=2544851
# [4651/5000] team_id=3961153
# [4701/5000] team_id=2425230
# [4751/5000] team_id=5200855
# [4801/5000] team_id=9271529
# [4851/5000] team_id=1169113
# [4901/5000] team_id=1325119
# [4951/5000] team_id=2685005
# [5000/5000] team_id=7358791
# Saved: team_hero_df.csv
# team_hero_df shape: (169555, 10)
#  team_id  hero_id                       name primary_attr attack_type  games_played  wins  winrate localized_name_x localized_name_y
#  7119388       19         npc_dota_hero_tiny          str       Melee           171   111   0.6491             Tiny             Tiny
#  7119388       86       npc_dota_hero_rubick          int      Ranged           162    95   0.5864           Rubick           Rubick
#  7119388      129         npc_dota_hero_mars          str       Melee           147    84   0.5714             Mars             Mars
#  7119388       17 npc_dota_hero_storm_spirit          int      Ranged           125    84   0.6720     Storm Spirit     Storm Spirit
#  7119388      106 npc_dota_hero_ember_spirit          agi       Melee           117    73   0.6239     Ember Spirit     Ember Spirit

# %%
## data frames we have so far

## teams_df
print(teams_df.head)
print("number of rows " + str(len(teams_df)))
## heroes_df
print(heroes_df.head)
print("number of rows " + str(len(heroes_df)))
## matches_teams_picks_bans
print(matches_teams_picks_bans.head)
print("number of rows " + str(len(matches_teams_picks_bans)))
# match_teams_df_nojson
print(match_teams_df_nojson.head)
print("number of rows " + str(len(match_teams_df_nojson)))
# match_picks_bans_df
print(match_picks_bans_df.head)
print("number of rows " + str(len(match_picks_bans_df)))
## team_hero information
print(team_hero_df.head)
print("number of rows " + str(len(team_hero_df)))
# Out:
# <bound method NDFrame.head of       team_id                  name         tag   rating  wins  losses  \
# 0     7119388           Team Spirit     TSpirit  1578.63   768     512
# 1     9572001            PARIVISION  PARIVISION  1559.36   179      91
# 2     8255888          BetBoom Team     BetBoom  1547.12   502     405
# 3     7412785          CyberBonch-1          CB  1520.12   267       1
# 4     8605863                Cloud9          C9  1497.49   326     243
# ...       ...                   ...         ...      ...   ...     ...
# 4995   470237  High Skill Dickheads         HSD  1015.33     1       0
# 4996  5635522            truestrike  Truestrike  1015.33     3       2
# 4997  3703112             Coca Cola              1015.32     1       0
# 4998  3326101               Too EzZ       !TE!.  1015.32     1       0
# 4999  7358791               SVALINN       SVL |  1015.32     1       0
#
#       last_match_time   last_match_time_iso  \
# 0          1752941276  2025-07-19T16:07:56Z
# 1          1753691348  2025-07-28T08:29:08Z
# 2          1753694464  2025-07-28T09:21:04Z
# 3          1639928575  2021-12-19T15:42:55Z
# 4          1726305637  2024-09-14T09:20:37Z
# ...               ...                   ...
# 4995       1415415973  2014-11-08T03:06:13Z
# 4996       1541933203  2018-11-11T10:46:43Z
# 4997       1753812712  2025-07-29T18:11:52Z
# 4998       1473512110  2016-09-10T12:55:10Z
# 4999       1567611598  2019-09-04T15:39:58Z
#
#                                                logo_url
# 0     https://cdn.steamusercontent.com/ugc/183917912...
# 1     https://cdn.steamusercontent.com/ugc/247650869...
# 2     https://cdn.steamusercontent.com/ugc/999542643...
# 3     https://cdn.steamusercontent.com/ugc/184253787...
# 4     https://cdn.steamusercontent.com/ugc/239994188...
# ...                                                 ...
# 4995  https://cdn.steamusercontent.com/ugc/111942269...
# 4996  https://cdn.steamusercontent.com/ugc/242450252...
# 4997                                               None
# 4998                                               None
# 4999  https://cdn.steamusercontent.com/ugc/793118374...
#
# [5000 rows x 9 columns]>
# number of rows 5000
# <bound method NDFrame.head of       id                          name  localized_name primary_attr  \
# 0      1        npc_dota_hero_antimage       Anti-Mage          agi
# 1      2             npc_dota_hero_axe             Axe          str
# 2      3            npc_dota_hero_bane            Bane          all
# 3      4     npc_dota_hero_bloodseeker     Bloodseeker          agi
# 4      5  npc_dota_hero_crystal_maiden  Crystal Maiden          int
# ..   ...                           ...             ...          ...
# 121  135     npc_dota_hero_dawnbreaker     Dawnbreaker          str
# 122  136           npc_dota_hero_marci           Marci          all
# 123  137    npc_dota_hero_primal_beast    Primal Beast          str
# 124  138          npc_dota_hero_muerta          Muerta          int
# 125  145             npc_dota_hero_kez             Kez          agi
#
#     attack_type                                    roles  legs
# 0         Melee                       Carry,Escape,Nuker     2
# 1         Melee         Initiator,Durable,Disabler,Carry     2
# 2        Ranged           Support,Disabler,Nuker,Durable     4
# 3         Melee           Carry,Disabler,Nuker,Initiator     2
# 4        Ranged                   Support,Disabler,Nuker     2
# ..          ...                                      ...   ...
# 121       Melee                            Carry,Durable     2
# 122       Melee  Support,Carry,Initiator,Disabler,Escape     2
# 123       Melee               Initiator,Durable,Disabler     2
# 124      Ranged                     Carry,Nuker,Disabler     2
# 125       Melee                    Carry,Escape,Disabler     2
#
# [126 rows x 7 columns]>
# number of rows 126
# <bound method NDFrame.head of          match_id  radiant_team_id  dire_team_id  start_time  \
# 0      7116526799          8680612       8971308  1682042521
# 1      7116656225          8893835       8864178  1682049626
# 2      7116662198          8629315       8629318  1682050090
# 3      7116708252          8864178       8893835  1682052312
# 4      7116718813          8863825       8736661  1682053231
# ...           ...              ...           ...         ...
# 65761  8409752513          9829468       9471746  1754753649
# 65762  8409798809          9844322       9844313  1754755382
# 65763  8409825381          9586122       9758040  1754756589
# 65764  8409828954          9824555       9209455  1754756566
# 65765  8409857991          9844322       9844313  1754757717
#
#              start_time_iso  radiant_win  winner_team_id  duration  \
# 0      2023-04-21T02:02:01Z        False         8971308      1849
# 1      2023-04-21T04:00:26Z         True         8893835      1718
# 2      2023-04-21T04:08:10Z         True         8629315      2180
# 3      2023-04-21T04:45:12Z         True         8864178      2151
# 4      2023-04-21T05:00:31Z        False         8736661      2584
# ...                     ...          ...             ...       ...
# 65761  2025-08-09T15:34:09Z         True         9829468      2365
# 65762  2025-08-09T16:03:02Z        False         9844313      1552
# 65763  2025-08-09T16:23:09Z        False         9758040      2260
# 65764  2025-08-09T16:22:46Z         True         9824555      1863
# 65765  2025-08-09T16:41:57Z         True         9844322      1408
#
#        radiant_score  dire_score  ...  team_id22 order22 isPick23 hero_id23  \
# 0                 10          42  ...  8971308.0    21.0     True      93.0
# 1                 34          13  ...  8864178.0    21.0     True     126.0
# 2                 43          27  ...  8629318.0    21.0     True     106.0
# 3                 39          20  ...  8893835.0    21.0     True       9.0
# 4                 20          38  ...  8736661.0    21.0     True      43.0
# ...              ...         ...  ...        ...     ...      ...       ...
# 65761             55          28  ...  9471746.0    21.0     True     110.0
# 65762             22          18  ...  9844313.0    21.0     True      34.0
# 65763             24          39  ...  9758040.0    21.0     True     119.0
# 65764             36          12  ...  9209455.0    21.0     True     104.0
# 65765             26          12  ...  9844313.0    21.0     True     129.0
#
#        team_id23  order23  isPick24 hero_id24  team_id24  order24
# 0      8680612.0     22.0      True      92.0  8971308.0     23.0
# 1      8893835.0     22.0      True      56.0  8864178.0     23.0
# 2      8629315.0     22.0      True      56.0  8629318.0     23.0
# 3      8864178.0     22.0      True      52.0  8893835.0     23.0
# 4      8863825.0     22.0      True      95.0  8736661.0     23.0
# ...          ...      ...       ...       ...        ...      ...
# 65761  9471746.0     22.0      True      28.0  9829468.0     23.0
# 65762  9844313.0     22.0      True     136.0  9844322.0     23.0
# 65763  9758040.0     22.0      True      85.0  9586122.0     23.0
# 65764  9209455.0     22.0      True     102.0  9824555.0     23.0
# 65765  9844313.0     22.0      True     104.0  9844322.0     23.0
#
# [65766 rows x 109 columns]>
# number of rows 65766
# <bound method NDFrame.head of          match_id  radiant_team_id  dire_team_id  start_time  \
# 0      7116526799          8680612       8971308  1682042521
# 1      7116656225          8893835       8864178  1682049626
# 2      7116662198          8629315       8629318  1682050090
# 3      7116708252          8864178       8893835  1682052312
# 4      7116718813          8863825       8736661  1682053231
# ...           ...              ...           ...         ...
# 65761  8409752513          9829468       9471746  1754753649
# 65762  8409798809          9844322       9844313  1754755382
# 65763  8409825381          9586122       9758040  1754756589
# 65764  8409828954          9824555       9209455  1754756566
# 65765  8409857991          9844322       9844313  1754757717
#
#              start_time_iso  radiant_win  winner_team_id  duration  \
# 0      2023-04-21T02:02:01Z        False         8971308      1849
# 1      2023-04-21T04:00:26Z         True         8893835      1718
# 2      2023-04-21T04:08:10Z         True         8629315      2180
# 3      2023-04-21T04:45:12Z         True         8864178      2151
# 4      2023-04-21T05:00:31Z        False         8736661      2584
# ...                     ...          ...             ...       ...
# 65761  2025-08-09T15:34:09Z         True         9829468      2365
# 65762  2025-08-09T16:03:02Z        False         9844313      1552
# 65763  2025-08-09T16:23:09Z        False         9758040      2260
# 65764  2025-08-09T16:22:46Z         True         9824555      1863
# 65765  2025-08-09T16:41:57Z         True         9844322      1408
#
#        radiant_score  dire_score  leagueid  \
# 0                 10          42     15136
# 1                 34          13     15109
# 2                 43          27     14659
# 3                 39          20     15109
# 4                 20          38     15126
# ...              ...         ...       ...
# 65761             55          28     18419
# 65762             22          18     18509
# 65763             24          39     18491
# 65764             36          12     18419
# 65765             26          12     18509
#
#                                              league_name patch
# 0      DPC 2023 SA Spring Tour Division II – presente...  7.33
# 1                                        Ancients League  7.33
# 2                                         Destiny league  7.33
# 3                                        Ancients League  7.33
# 4      DPC 2023 SEA Spring Tour Division II - present...  7.33
# ...                                                  ...   ...
# 65761                                        Boss Battle  7.39
# 65762                                 Europa Masters Cup  7.39
# 65763                                  CIS Battle Dota 2  7.39
# 65764                                        Boss Battle  7.39
# 65765                                 Europa Masters Cup  7.39
#
# [65766 rows x 13 columns]>
# number of rows 65766
# <bound method NDFrame.head of            match_id  order  is_pick  hero_id  team_side  team_id
# 0        7116526799      0    False       58          0  8680612
# 1        7116526799      1    False       75          1  8971308
# 2        7116526799      2    False       85          0  8680612
# 3        7116526799      3    False      137          1  8971308
# 4        7116526799      4     True      101          0  8680612
# ...             ...    ...      ...      ...        ...      ...
# 1564924  8409857991     19    False      135          0  9844322
# 1564925  8409857991     20    False       38          0  9844322
# 1564926  8409857991     21    False      114          1  9844313
# 1564927  8409857991     22     True      129          1  9844313
# 1564928  8409857991     23     True      104          0  9844322
#
# [1564929 rows x 6 columns]>
# number of rows 1564929
# <bound method NDFrame.head of         team_id  hero_id                         name primary_attr  \
# 0       7119388       19           npc_dota_hero_tiny          str
# 1       7119388       86         npc_dota_hero_rubick          int
# 2       7119388      129           npc_dota_hero_mars          str
# 3       7119388       17   npc_dota_hero_storm_spirit          int
# 4       7119388      106   npc_dota_hero_ember_spirit          agi
# ...         ...      ...                          ...          ...
# 169550  7358791       21     npc_dota_hero_windrunner          all
# 169551  7358791       27  npc_dota_hero_shadow_shaman          int
# 169552  7358791       79   npc_dota_hero_shadow_demon          int
# 169553  7358791       16      npc_dota_hero_sand_king          all
# 169554  7358791       41  npc_dota_hero_faceless_void          agi
#
#        attack_type  games_played  wins  winrate localized_name_x  \
# 0            Melee           171   111   0.6491             Tiny
# 1           Ranged           162    95   0.5864           Rubick
# 2            Melee           147    84   0.5714             Mars
# 3           Ranged           125    84   0.6720     Storm Spirit
# 4            Melee           117    73   0.6239     Ember Spirit
# ...            ...           ...   ...      ...              ...
# 169550      Ranged             1     1   1.0000       Windranger
# 169551      Ranged             1     1   1.0000    Shadow Shaman
# 169552      Ranged             1     1   1.0000     Shadow Demon
# 169553       Melee             1     1   1.0000        Sand King
# 169554       Melee             1     1   1.0000    Faceless Void
#
#        localized_name_y
# 0                  Tiny
# 1                Rubick
# 2                  Mars
# 3          Storm Spirit
# 4          Ember Spirit
# ...                 ...
# 169550       Windranger
# 169551    Shadow Shaman
# 169552     Shadow Demon
# 169553        Sand King
# 169554    Faceless Void
#
# [169555 rows x 10 columns]>
# number of rows 169555

# %%
## that is all for data collection for now
